# %%
import scanpy as sc
import pandas as pd
import numpy as np
import random
from scipy import sparse
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

import Utility.pseudobulk as pseudobulk

# %%
cd 1-sc_practice/Differential_Gene_Analysis/
# Out:
# /project/imoskowitz/yubin/1-sc_practice/Differential_Gene_Analysis

# %%
adata = sc.read_h5ad("/project/imoskowitz/yubin/1-sc_practice/Data/SmoNull_Brain_system.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 38311 × 33696
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Condition', 'Library.ident', 'Sample', 'Replicate', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.1', 'seurat_clusters', 'doublet_finder', 'doublet_status', 'S.Score', 'G2M.Score', 'Phase', 'old.ident', 'SCT_snn_res.1', 'SCT_snn_res.4', 'Extended_mouse_gastrulation_label', 'System', 'ClusterSystem', 'total_counts', 'size_factors', 'Celltype', 'leiden_0_25_log1p', 'leiden_0_25_scran', 'leiden_0_25_pearson', 'leiden_0_5_log1p', 'leiden_0_5_scran', 'leiden_0_5_pearson', 'leiden_1_log1p', 'leiden_1_scran', 'leiden_1_pearson', 'leiden_2_log1p', 'leiden_2_scran', 'leiden_2_pearson', 'leiden_3_log1p', 'leiden_3_scran', 'leiden_3_pearson', 'leiden_5_log1p', 'leiden_5_scran', 'leiden_5_pearson', 'manual_celltype_annotation'
#     var: 'features', 'highly_variable_log1p', 'highly_variable_nbatches_log1p', 'highly_variable_intersection_log1p', 'mean', 'std', 'means', 'variances', 'residual_variances', 'highly_variable_pearson', 'highly_variable_nbatches_pearson', 'highly_variable_intersection_pearson', 'highly_variable_rank(pearson)', 'dispersions', 'dispersions_norm', 'highly_variable_scran', 'highly_variable_nbatches_scran', 'highly_variable_intersection_scran'
#     uns: 'Celltype_colors', 'ClusterSystem_colors', 'Condition_colors', 'Library.ident_colors', 'X_umap_log1p', 'X_umap_pearson', 'X_umap_scran', 'hvg_log1p', 'hvg_pearson', 'hvg_scran', 'leiden_0_25_log1p', 'leiden_0_25_pearson', 'leiden_0_25_scran', 'leiden_0_5_log1p', 'leiden_0_5_pearson', 'leiden_0_5_scran', 'leiden_1_log1p', 'leiden_1_pearson', 'leiden_1_scran', 'leiden_2_log1p', 'leiden_2_pearson', 'leiden_2_scran', 'leiden_3_log1p', 'leiden_3_pearson', 'leiden_3_scran', 'leiden_5_log1p', 'leiden_5_pearson', 'leiden_5_scran', 'manual_celltype_annotation_colors', 'neighbors_log1p', 'neighbors_pearson', 'neighbors_scran', 'pca'
#     obsm: 'X_pca_harmony_log1p', 'X_pca_harmony_pearson', 'X_pca_harmony_scran', 'X_pca_log1p', 'X_pca_pearson', 'X_pca_scran', 'X_umap_log1p', 'X_umap_pearson', 'X_umap_scran'
#     varm: 'PCs'
#     layers: 'analytic_pearson_residuals', 'log1p_norm', 'raw_counts', 'scran_normalization'
#     obsp: 'neighbors_log1p_connectivities', 'neighbors_log1p_distances', 'neighbors_pearson_connectivities', 'neighbors_pearson_distances', 'neighbors_scran_connectivities', 'neighbors_scran_distances'

# %%
# Display the count for each cell type and by condition (manually labeled)
pd.crosstab(adata.obs["manual_celltype_annotation"], adata.obs["Condition"])
# Out:
# Condition                   Control  SmoNull
# manual_celltype_annotation
# Forebrain                      3419     2910
# Hindbrain                      4502     6505
# Midbrain                       3220     3663
# Midline                        4127       68

# %% [markdown]
# Pseudobulk steps:
#
# 0. Choose a cluster/celltype
# 1. Group by Condition + replicate
# 2. Find total of gene count within the group for each gene (axis = 0)
# 3. Create a new anndata that stores the total count, as well as gene name. Should have format like this:
#
# Condition + replicate| Gene1 | Gene 2 | ... | Gene n
# ---------------------|-------|--------|-----|--------
# Control_1 | 0 | 1 | ... | 2
# Smo_null | 0 | 100 | ... | 23
#
# 4. Make sure you include metadatas for obs such as the cell type, cluster, condition, replicate, etc

# %%
print(len(adata[adata.obs["Condition"]=="Control"].obs["Sample"].cat.categories))
print(len(adata[adata.obs["Condition"]=="SmoNull"].obs["Sample"].cat.categories))
# Out:
# 3
# 3

# %%
adata[adata.obs["Sample"] == "Sample1"].obs.Condition.unique()
# Out:
# ['Control']
# Categories (1, object): ['Control']

# %%
[adata.obs["Condition"].iloc[0]]
# Out:
# ['Control']

# %% [markdown]
# # Start of  Pseudobulk

# %%
# Convert X to raw
adata.X = adata.layers["raw_counts"]
hindbrain_subset = adata[adata.obs.manual_celltype_annotation == "Hindbrain"]
hindbrain_pb = pseudobulk.run_pseudobulk(hindbrain_subset, by = "Sample", min_cells = 0, metadatas = ["manual_celltype_annotation", "Library.ident"])
hindbrain_pb
hindbrain_dds = pseudobulk.run_deseq(hindbrain_pb, "~Condition", min_samples=0)
# Out:
# /home/yubin/.conda/envs/scRNAseq_python/lib/python3.11/site-packages/scanpy/preprocessing/_simple.py:293: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var["n_cells"] = number
# Fitting size factors...
# ... done in 0.01 seconds.
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting dispersions...
# ... done in 3.01 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.56 seconds.
#
# Fitting MAP dispersions...
# ... done in 3.41 seconds.
#
# Fitting LFCs...
# ... done in 2.31 seconds.
#
# Calculating cook's distance...
# ... done in 0.02 seconds.
#
# Replacing 0 outlier genes.

# %%
sc.tl.pca(hindbrain_dds)
sc.pl.pca_variance_ratio(hindbrain_dds)

# %%
sc.pl.pca(hindbrain_dds, color = "Library.ident", size=200)

# %% [markdown]
# ## With Batch in design factor

# %%
# Convert X to raw
adata.X = adata.layers["raw_counts"]

# %%
hindbrain_subset = adata[adata.obs.manual_celltype_annotation == "Hindbrain"]

# %%
hindbrain_pb = pseudobulk.run_pseudobulk(hindbrain_subset, by = "Sample", min_cells = 0, metadatas = ["manual_celltype_annotation", "Library.ident"])
# Out:
# /home/yubin/.conda/envs/scRNAseq_python/lib/python3.11/site-packages/scanpy/preprocessing/_simple.py:293: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var["n_cells"] = number

# %%
hindbrain_pb
# Out:
# AnnData object with n_obs × n_vars = 6 × 33696
#     obs: 'Condition', 'Replicate', 'manual_celltype_annotation', 'Library.ident'

# %%
hindbrain_dds = pseudobulk.run_deseq(hindbrain_pb, "~Library.ident+Condition", min_samples=0)
# Out:
# Using None as control genes, passed at DeseqDataSet initialization
# Fitting size factors...
# ... done in 0.01 seconds.
#
# Fitting dispersions...
# ... done in 2.69 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.71 seconds.
#
# /home/yubin/.conda/envs/scRNAseq_python/lib/python3.11/site-packages/pydeseq2/dds.py:541: UserWarning: As the residual degrees of freedom is less than 3, the distribution of log dispersions is especially asymmetric and likely to be poorly estimated by the MAD.
#   self.fit_dispersion_prior()
# Fitting MAP dispersions...
# ... done in 3.21 seconds.
#
# Fitting LFCs...
# ... done in 2.88 seconds.
#
# Calculating cook's distance...
# ... done in 0.01 seconds.
#
# Replacing 0 outlier genes.

# %%
# TODO: Add percent variance
sc.tl.pca(hindbrain_dds)
sc.pl.pca_variance_ratio(hindbrain_dds)

# %%
sc.pl.pca(hindbrain_dds, color = "Condition", size=200)

# %%
stat_res = DeseqStats(hindbrain_dds, n_cpus=8, contrast=("Condition", "Control", "SmoNull"), )

# %%
stat_res.summary()
# Out:
# Running Wald tests...
# Log2 fold change & Wald test p-value: Condition Control vs SmoNull
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# Xkr4                489.923797       -0.173432  0.145978 -1.188072  0.234805
# Gm1992               23.294824       -0.051467  0.418526 -0.122972  0.902129
# Gm19938              12.049165       -0.394003  0.563621 -0.699056  0.484517
# Gm37381               0.504649       -2.149422  3.358629 -0.639970  0.522192
# Rp1                   7.060131       -0.226565  0.788342 -0.287394  0.773811
# ...                        ...             ...       ...       ...       ...
# ENSMUSG00000095523    0.000000             NaN       NaN       NaN       NaN
# ENSMUSG00000095475    0.000000             NaN       NaN       NaN       NaN
# ENSMUSG00000094855    0.000000             NaN       NaN       NaN       NaN
# ENSMUSG00000095019    0.000000             NaN       NaN       NaN       NaN
# ENSMUSG00000095041  299.150421       -0.544666  0.257583 -2.114525  0.034470
#
#                         padj
# Xkr4                0.444052
# Gm1992              0.953270
# Gm19938             0.690916
# Gm37381                  NaN
# Rp1                 0.882547
# ...                      ...
# ENSMUSG00000095523       NaN
# ENSMUSG00000095475       NaN
# ENSMUSG00000094855       NaN
# ENSMUSG00000095019       NaN
# ENSMUSG00000095041  0.117913
#
# [33696 rows x 6 columns]
# ... done in 11.84 seconds.

# %%
de = stat_res.results_df

# %%
de
# Out:
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# Xkr4                489.923797       -0.173432  0.145978 -1.188072  0.234805
# Gm1992               23.294824       -0.051467  0.418526 -0.122972  0.902129
# Gm19938              12.049165       -0.394003  0.563621 -0.699056  0.484517
# Gm37381               0.504649       -2.149422  3.358629 -0.639970  0.522192
# Rp1                   7.060131       -0.226565  0.788342 -0.287394  0.773811
# ...                        ...             ...       ...       ...       ...
# ENSMUSG00000095500    0.375806        0.649481  3.541146  0.183410  0.854477
# Csprs                 0.132808       -0.312305  4.427542 -0.070537  0.943766
# ENSMUSG00000096808    0.885288       -1.580838  2.209688 -0.715412  0.474354
# ENSMUSG00000095742   10.259770        0.051710  0.588223  0.087909  0.929949
# ENSMUSG00000095041  299.150421       -0.544666  0.257583 -2.114525  0.034470
#
#                         padj
# Xkr4                0.441981
# Gm1992              0.953237
# Gm19938             0.689538
# Gm37381                  NaN
# Rp1                      NaN
# ...                      ...
# ENSMUSG00000095500       NaN
# Csprs                    NaN
# ENSMUSG00000096808       NaN
# ENSMUSG00000095742  0.966775
# ENSMUSG00000095041  0.117132
#
# [26519 rows x 6 columns]

# %%
# de.to_csv("DEG_Hindbrain_Control_vs_SmoNull_filter_10_cells")

# %% [markdown]
# Filter out genes present in less than i pseudobulk samples

# %%
for i in range(7):
    hindbrain_dds = pseudobulk.run_deseq(hindbrain_pb, "~Condition", min_samples=i)
    stat_res = DeseqStats(hindbrain_dds, n_cpus=8, contrast=("Condition", "Control", "SmoNull"))
    stat_res.summary()
    de = stat_res.results_df
    de.to_csv("/project/imoskowitz/yubin/1-sc_practice/Differential_Gene_Analysis/DataFrames/Post-pseudobulk-filter/DEG_Hindbrain_Control_vs_SmoNull_filter_" + str(i) + "_cells")
    print(len(de))

# %% [markdown]
# Filtering out genes present in less than i cells before pseudobulking

# %%
print(hindbrain_subset.X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 35036790 stored elements and shape (11007, 33696)>
#   Coords	Values
#   (0, 18)	1.0
#   (0, 22)	2.0
#   (0, 25)	1.0
#   (0, 42)	3.0
#   (0, 43)	1.0
#   (0, 49)	4.0
#   (0, 68)	1.0
#   (0, 78)	1.0
#   (0, 123)	1.0
#   (0, 125)	2.0
#   (0, 136)	3.0
#   (0, 150)	2.0
#   (0, 156)	2.0
#   (0, 174)	1.0
#   (0, 205)	2.0
#   (0, 227)	1.0
#   (0, 230)	17.0
#   (0, 251)	1.0
#   (0, 295)	2.0
#   (0, 299)	1.0
#   (0, 308)	1.0
#   (0, 313)	1.0
#   (0, 338)	1.0
#   (0, 346)	1.0
#   (0, 350)	1.0
#   :	:
#   (11006, 32766)	3.0
#   (11006, 32767)	1.0
#   (11006, 32768)	2.0
#   (11006, 32771)	1.0
#   (11006, 32786)	1.0
#   (11006, 32804)	1.0
#   (11006, 32811)	3.0
#   (11006, 32818)	5.0
#   (11006, 32822)	1.0
#   (11006, 32831)	1.0
#   (11006, 32836)	1.0
#   (11006, 32840)	2.0
#   (11006, 32843)	1.0
#   (11006, 32860)	2.0
#   (11006, 32863)	1.0
#   (11006, 32866)	1.0
#   (11006, 32891)	3.0
#   (11006, 32906)	1.0
#   (11006, 32909)	2.0
#   (11006, 33631)	3.0
#   (11006, 33634)	3.0
#   (11006, 33637)	1.0
#   (11006, 33638)	2.0
#   (11006, 33641)	1.0
#   (11006, 33695)	1.0

# %%
for i in range(5):
    hindbrain_pb = pseudobulk.run_pseudobulk(hindbrain_subset, by = "Sample", metadatas = "manual_celltype_annotation", min_cells=i)
    hindbrain_dds = pseudobulk.run_deseq(hindbrain_pb, "~Condition", min_cells=0)
    stat_res = DeseqStats(hindbrain_dds, n_cpus=8, contrast=("Condition", "Control", "SmoNull"))
    stat_res.summary()
    de = stat_res.results_df
    de.to_csv("/project/imoskowitz/yubin/1-sc_practice/Differential_Gene_Analysis/DataFrames/DEG_Hindbrain_Control_vs_SmoNull_pre_filter_" + str(i) + "_cells")
    print(len(de))
