# %% [markdown]
# generate MA plots for different pre and post filter settings

# %%
import pandas as pd
from pathlib import Path    

import matplotlib.pyplot as plt

# Custom MA_plot function
import sys
sys.path.append('/project/imoskowitz/yubin/1-sc_practice/Differential_Gene_Analysis/Utility/')
import MA_plot

# %%
pre_filters_path= Path("/project/imoskowitz/yubin/1-sc_practice/Differential_Gene_Analysis/DataFrames/Pre-pseudobulk-filter")
post_filters_path= Path("/project/imoskowitz/yubin/1-sc_practice/Differential_Gene_Analysis/DataFrames/Post-pseudobulk-filter")
pre_filters = []
for file in sorted(pre_filters_path.iterdir()):
    pre_filters.append(pd.read_csv(file))
    
post_filters = []
for file in sorted(post_filters_path.iterdir()):
    post_filters.append(pd.read_csv(file))

# %%
pre_filters[0]
# Out:
#        Unnamed: 0.1          Unnamed: 0    baseMean  log2FoldChange     lfcSE  \
# 0                 0                Xkr4  489.923797       -0.173432  0.145978
# 1                 1              Gm1992   23.294824       -0.051467  0.418526
# 2                 2             Gm19938   12.049165       -0.394003  0.563621
# 3                 3             Gm37381    0.504649       -2.149422  3.358629
# 4                 4                 Rp1    7.060131       -0.226565  0.788342
# ...             ...                 ...         ...             ...       ...
# 33691         33691  ENSMUSG00000095523    0.000000             NaN       NaN
# 33692         33692  ENSMUSG00000095475    0.000000             NaN       NaN
# 33693         33693  ENSMUSG00000094855    0.000000             NaN       NaN
# 33694         33694  ENSMUSG00000095019    0.000000             NaN       NaN
# 33695         33695  ENSMUSG00000095041  299.150421       -0.544666  0.257583
#
#            stat    pvalue      padj  Significance diff_expr
# 0     -1.188072  0.234805  0.444052         False        NS
# 1     -0.122972  0.902129  0.953270         False        NS
# 2     -0.699056  0.484517  0.690916         False        NS
# 3     -0.639970  0.522192       NaN         False        NS
# 4     -0.287394  0.773811  0.882547         False        NS
# ...         ...       ...       ...           ...       ...
# 33691       NaN       NaN       NaN         False        NS
# 33692       NaN       NaN       NaN         False        NS
# 33693       NaN       NaN       NaN         False        NS
# 33694       NaN       NaN       NaN         False        NS
# 33695 -2.114525  0.034470  0.117913         False        NS
#
# [33696 rows x 10 columns]

# %%
fig, axs = plt.subplots(nrows = 2, ncols= 3, figsize=(12,6), layout = "constrained")
axs_flatten = axs.flatten()
for i, filter in enumerate(pre_filters):
    MA_plot.custom_MA_plot(filter, axs_flatten[i], title = "MA Plot of " + str(i) +" cell filter")

fig.savefig("/project/imoskowitz/yubin/1-sc_practice/Differential_Gene_Analysis/Figures/MA_plot_pre_filter.png")

# %%
fig, axs = plt.subplots(nrows = 2, ncols= 4, figsize=(16, 6), layout = "constrained")
axs_flatten = axs.flatten()
for i, filter in enumerate(post_filters):
    MA_plot.custom_MA_plot(filter, axs_flatten[i], title = "MA Plot of " + str(i) +" sample filter")
fig.savefig("/project/imoskowitz/yubin/1-sc_practice/Differential_Gene_Analysis/Figures/MA_plot_post_filter.png")
