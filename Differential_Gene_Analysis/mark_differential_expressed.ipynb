# %%
import pandas as pd
from pathlib import Path
from load_pseudobulk_filters import load_filters

# %%
df_list = load_filters()

# %%
df_list[0]
# Out:
#                Unnamed: 0    baseMean  log2FoldChange     lfcSE      stat  \
# 0                    Xkr4  489.923797       -0.173432  0.145978 -1.188072
# 1                  Gm1992   23.294824       -0.051467  0.418526 -0.122972
# 2                 Gm19938   12.049165       -0.394003  0.563621 -0.699056
# 3                 Gm37381    0.504649       -2.149422  3.358629 -0.639970
# 4                     Rp1    7.060131       -0.226565  0.788342 -0.287394
# ...                   ...         ...             ...       ...       ...
# 33691  ENSMUSG00000095523    0.000000             NaN       NaN       NaN
# 33692  ENSMUSG00000095475    0.000000             NaN       NaN       NaN
# 33693  ENSMUSG00000094855    0.000000             NaN       NaN       NaN
# 33694  ENSMUSG00000095019    0.000000             NaN       NaN       NaN
# 33695  ENSMUSG00000095041  299.150421       -0.544666  0.257583 -2.114525
#
#          pvalue      padj
# 0      0.234805  0.444052
# ...
